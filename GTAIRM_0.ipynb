# %% [markdown]
# <a href="https://colab.research.google.com/github/joehiggi/graph-theoretic-applications-in-insurance-risk-management/blob/main/GTAIRM_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graph Theoretic Applications in Insurance Risk Management

# %% [markdown]
# The purpose of this notebook is to research graph theroetic applications in insurance risk management. Namely to determine if an aggregate metric can be assessed to determine exposure to risk, and to study if there are network effects of exposure in firm investment accounts to industry volatility.

# %% [markdown]
# *Importing packages*

# %%
import pandas as pd
import numpy as np
import datasets
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Load the entire dataset
raw_dataset = datasets.load_dataset("eloukas/edgar-corpus", "full")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_11222/210260679.py in <cell line: 0>()
#       1 # Load the entire dataset
# ----> 2 raw_dataset = datasets.load_dataset("eloukas/edgar-corpus", "full")
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1390
#    1391     # Create a dataset builder
# -> 1392     builder_instance = load_dataset_builder(
#    1393         path=path,
#    1394         name=name,
#
# ...

# %% [markdown]
# ### References
# - https://arxiv.org/pdf/2109.14394
